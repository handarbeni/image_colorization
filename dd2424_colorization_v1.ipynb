# %%
import numpy as np
import os
import glob
from skimage.color import rgb2lab, lab2rgb, rgb2gray, gray2rgb
from skimage.transform import resize
from skimage.io import imsave, imread
import tensorflow as tf
from tensorflow import data as tfdata
from keras import backend as K
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
from keras.models import Model
from keras.callbacks import TensorBoard
from keras.preprocessing.image import img_to_array, load_img
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing.image import img_to_array, load_img

# %%
sess = tf.Session()
K.set_session(sess)
sess = None

# %% [markdown]
# #### Define Path for Generating Training and Valididation TFRecord

# %%
'''PATH_TRAIN_RAW_IMG = r"../dd2424_project/tiny-imagenet-200/train"
PATH_VAL_RAW_IMG = r"../dd2424_project/tiny-imagenet-200/val/images"
PATH_TRAIN_TF = "tf_data/train_images.tfrecord"
PATH_VAL_TF = "tf_data/val_images.tfrecord"
PATH_TRAIN_RAW_IMG = r"../dd2424_project/imagenet/imagenet_12k"
PATH_VAL_RAW_IMG = r"../dd2424_project/imagenet/imagenet_12k"
PATH_TRAIN_TF = "tf_data_imagenet/train_images.tfrecord"
PATH_VAL_TF = "tf_data_imagenet/val_images.tfrecord"
PATH_TRAIN_RAW_IMG = r"../dd2424_project/imagenet_cat/images"
PATH_VAL_RAW_IMG = r"../dd2424_project/imagenet_cat/images"
PATH_TRAIN_TF = "tf_data_imagenet_cat/train_images.tfrecord"
PATH_VAL_TF = "tf_data_imagenet_cat/val_images.tfrecord"'''
PATH_TRAIN_RAW_IMG = r"../dd2424_project/imagenet_"
PATH_VAL_RAW_IMG = r"../dd2424_project/imagenet_"
PATH_TRAIN_TF = "tf_data_imagenet_5k/train_images.tfrecord"
PATH_VAL_TF = "tf_data_imagenet_5k/val_images.tfrecord"

# %%
if not os.path.exists('model_weights/'):
    os.makedirs('model_weights/')
if not os.path.exists('predicted_images/'):
    os.makedirs('predicted_images/')
if not os.path.exists('tf_data/'):
    os.makedirs('tf_data/')

# %% [markdown]
# #### Define required funtion

# %%
## Get pre-trained InceptionResNetV2

inception_act = None
def get_inception():
    global feature_extract_model, inception_act
    
    inception_act = InceptionResNetV2(input_shape=(EMBEDDING_IMG_SIZE, EMBEDDING_IMG_SIZE, 3),
                                             include_top=True, weights='imagenet')
    inception_act.graph = tf.get_default_graph()
    inception_act.trainable = False

# %%
## Get last layer output of InceptionResNetV2

def get_last_layer_inception(grayscaled_img, batch_size=100):
    feature_map = inception_act.predict(grayscaled_img, batch_size=batch_size)
    return feature_map

# %%
## Extract high-level features from InceptionResNetV2 

def extract_features(grayscaled_rgb, batch_size=100):
    if inception_act is None:
        get_inception()
        
    grayscaled_rgb_resized = []
    
    for img in grayscaled_rgb:
        img = resize(img, (EMBEDDING_IMG_SIZE, EMBEDDING_IMG_SIZE, 3), mode='constant')
        grayscaled_rgb_resized.append(img)
        
    grayscaled_rgb_resized = np.array(grayscaled_rgb_resized)
    grayscaled_rgb_resized = preprocess_input(grayscaled_rgb_resized)
    
    with inception_act.graph.as_default():
        features = get_last_layer_inception(grayscaled_rgb_resized, batch_size)
        features = features.reshape((-1,1000))
    
    return features

# %%
## process batch of image for training

def process_img_batch(X, batch_size):
    grayscaled_rgb = gray2rgb(rgb2gray(X))
    lab_batch = rgb2lab(X)
    X_batch = lab_batch[:, :, :, 0]
    X_batch = X_batch.reshape(X_batch.shape + (1,))
    X_batch = 2 * X_batch / 100 - 1.
    Y_batch= lab_batch[:, :, :, 1:] / 127
    features = extract_features(grayscaled_rgb, batch_size)
    
    return ([X_batch, features], Y_batch)

# %%
## serialize batch of image into TFRecords

def serialize_records(X, writer, batch_size):
    [X_batch, features], Y_batch = process_img_batch(X, batch_size)
    
    for j, (img_l, embed, y) in enumerate(zip(X_batch, features, Y_batch)):
        img_l = resize(img_l, (IMG_SIZE, IMG_SIZE, 1), mode='constant')
        y = resize(y, (IMG_SIZE, IMG_SIZE, 2), mode='constant')
        
        example_dict = {
            'image_l': tf.train.Feature(float_list=tf.train.FloatList(value=img_l.flatten())),
            'image_ab': tf.train.Feature(float_list=tf.train.FloatList(value=y.flatten())),
            'image_features' : tf.train.Feature(float_list=tf.train.FloatList(value=embed.flatten()))
        }
        example_features = tf.train.Features(feature=example_dict)
        example = tf.train.Example(features=example_features)
        writer.write(example.SerializeToString())

# %%
## Generate TFRecords for training and validation data
## the TFRecords contain L* component of the image, ab component, extracted feature from InceptionResNetV2
def img_to_tf_records(path_to_images, tf_record_name, total_size, _type, batch_size=100, n_class = None):
    if os.path.exists(tf_record_name):
        print("remove old TF records!")
    else:
        if _type == 'train':
            folders = glob.glob(path_to_images + '*')
            files = []
            for i, folder in enumerate(folders):
                print(folder)
                if i < n_class:
                    files_temp = glob.glob(folder + '/images/*')
                    files_temp = files_temp[0:(total_size//n_class)]
                    files.append(files_temp)
            files = [y for x in files for y in x]
            
            
        elif _type == 'val':
            folders = glob.glob(path_to_images + '*')
            files = []
            for i, folder in enumerate(folders):
                print(folder)
                if i < 5:
                    files_temp = glob.glob(folder + '/images/*')
                    files_temp = files_temp[-110:-10]
                    files.append(files_temp)
            files = [y for x in files for y in x]
            

        print("panjang file: " + str(len(files)))
        files = sorted(files)

        options = tf.python_io.TFRecordOptions(tf.python_io.TFRecordCompressionType.ZLIB)
        writer = tf.python_io.TFRecordWriter(tf_record_name, options)

        size = max(EMBEDDING_IMG_SIZE, IMG_SIZE)

        X_buffer = []
        done_count = 0
        for i, file in enumerate(files):
            #print(file)
            try:
                X = imread(file)
            except:
                continue
            #print(file)
            X = resize(X, (size, size, 3), mode = 'constant')

            X_buffer.append(X)
            done_count += 1

            if len(X_buffer) >= batch_size:
                X_buffer = np.array(X_buffer)
                serialize_records(X_buffer, writer, batch_size)
                del X_buffer
                X_buffer = []
                print("Done %d / %d images" % (done_count, total_size))

        if len(X_buffer) != 0:
            X_buffer = np.array(X_buffer)
            serialize_records(X_buffer, writer, batch_size)
            del X_buffer

        print("Done %d / %d images" % (done_count, total_size))
        print("Finished preprocessed data to TFRecoeds")
        writer.close()

# %%
## Generate train TFRecords

def generate_train_data(batch_size, total_size, n_class):
    img_to_tf_records(PATH_TRAIN_RAW_IMG, PATH_TRAIN_TF, total_size, 'train', batch_size, n_class)

# %%
## Generate validation TFRecords

def generate_val_data(batch_size, total_size):
    img_to_tf_records(PATH_VAL_RAW_IMG, PATH_VAL_TF, total_size, 'val', batch_size)

# %%
## Read TFRecords and load it as Dataset

def construct_dataset(path_to_record, batch_size, sess):
    def parse_record(serialized_example):
        features = tf.parse_single_example(serialized_example,
                                          features={
                                              'image_l': tf.FixedLenFeature([IMG_SIZE, IMG_SIZE, 1], tf.float32),
                                              'image_ab': tf.FixedLenFeature([IMG_SIZE, IMG_SIZE, 2], tf.float32),
                                              'image_features': tf.FixedLenFeature([1000, ], tf.float32)
                                          })
        l, ab, embed = features['image_l'], features['image_ab'], features['image_features']
        return l, ab, embed
    
    dataset = tfdata.TFRecordDataset([path_to_record], 'ZLIB')
    dataset = dataset.map(parse_record, num_parallel_calls=2)
    dataset = dataset.repeat()
    dataset = dataset.batch(batch_size)
    dataset = dataset.shuffle(buffer_size=5)
    iterator = dataset.make_initializable_iterator()
    
    sess.run(iterator.initializer)
    next_batch = iterator.get_next()
    
    return dataset, next_batch

# %%
## Helper function to read data from TFRecords for training

def train_generator(batch_size):
    with tf.Session() as train_gen_session:
        dataset, next_batch = construct_dataset(PATH_TRAIN_TF, batch_size, train_gen_session)
        
        while True:
            try:
                l, ab, features = train_gen_session.run(next_batch)
                yield([l, features], ab)
            except:
                iterator = dataset.make_initializable_iterator()
                train_gen_session.run(iterator.initializer)
                next_batch = iterator.get_next()
                
                l, ab, features = train_gen_session.run(next_batch)
                yield([l, features], ab)

# %%
## Helper function to read data from TFRecords for validation

def val_batch_generator(batch_size):
    with tf.Session() as val_gen_session:
        dataset, next_batch = construct_dataset(PATH_VAL_TF, batch_size, val_gen_session)
        
        while True:
            try:
                l, ab, features = val_gen_session.run(next_batch)
                yield([l, features], ab)
            except:
                iterator = dataset.make_initializable_iterator()
                val_gen_session.run(iterator.initializer)
                next_batch = iterator.get_next()
                
                l, ab, features = val_gen_session.run(next_batch)
                yield([l, features], ab)

# %%
## Generate L*, a*, b* components and extracted features of the input image 
## The outputs are used for testing (predict the a* and b* component)

def preprocess_input_img_batch(X, batch_size=100):
    X_processed = X/255.
    X_grayscaled = gray2rgb(rgb2gray(X_processed))
    X_features = extract_features(X_grayscaled, batch_size)
    X_lab = rgb2lab(X_grayscaled)[:, :, :, 0]
    X_lab = X_lab.reshape(X_lab.shape + (1,))
    X_lab = 2*X_lab/100-1.
    
    return X_lab, X_features

# %%
## Write predicted picture in testing to png file

def postprocess_output_img(X_lab, y, orig_X, orig_Y, image_size=None):
    y *= 127.
    X_lab = (X_lab + 1) * 50.
    
    image_size = IMG_SIZE if image_size is None else image_size
    
    for i in range(len(y)):
        cur = np.zeros((image_size, image_size, 3))
        cur[:, :, 0] = X_lab[i, :, :, 0]
        cur[:, :, 1:] = y[i]
        res = lab2rgb(cur)
        res = resize(res, (orig_X[i], orig_Y[i], 3))
        imsave("predicted_images_cat/img_%d_predicted.png" % (i+1), res)

# %%
IMG_SIZE = 128 ## all images are resized to IMGxIMG
EMBEDDING_IMG_SIZE = 299 ## embedding size, InceptionResNetV2 only accept image with size of 299x299x3

# %% [markdown]
# #### Generate train and validation data (as TFRecords)

# %%
generate_train_data(100, 5000, 5)
# Out:
# ../dd2424_project/imagenet_obelisk
# ../dd2424_project/imagenet_palm
# ../dd2424_project/imagenet_cat
# ../dd2424_project/imagenet_shinkansen
# ../dd2424_project/imagenet_people
# panjang file: 5000
# Done 100 / 5000 images
# Done 200 / 5000 images
# Done 300 / 5000 images
# Done 400 / 5000 images
# Done 500 / 5000 images
# Done 600 / 5000 images
# Done 700 / 5000 images
# Done 800 / 5000 images
# Done 900 / 5000 images
# Done 1000 / 5000 images
# Done 1100 / 5000 images
# Done 1200 / 5000 images
# Done 1300 / 5000 images
# Done 1400 / 5000 images
# Done 1500 / 5000 images
# Done 1600 / 5000 images
# Done 1700 / 5000 images
# Done 1800 / 5000 images
# Done 1900 / 5000 images
# Done 2000 / 5000 images
# Done 2100 / 5000 images
# Done 2200 / 5000 images
# Done 2300 / 5000 images
# Done 2400 / 5000 images
# Done 2500 / 5000 images
# Done 2600 / 5000 images
# Done 2700 / 5000 images
# Done 2800 / 5000 images
# Done 2900 / 5000 images
# Done 3000 / 5000 images
# Done 3100 / 5000 images
# Done 3200 / 5000 images
# Done 3300 / 5000 images
# Done 3400 / 5000 images
# Done 3500 / 5000 images
# Done 3600 / 5000 images
# Done 3700 / 5000 images
# Done 3800 / 5000 images
# Done 3900 / 5000 images
# Done 4000 / 5000 images
# Done 4100 / 5000 images
# Done 4200 / 5000 images
# Done 4300 / 5000 images
# Done 4400 / 5000 images
# Done 4500 / 5000 images
# Done 4600 / 5000 images
# Done 4700 / 5000 images
# Done 4800 / 5000 images
# Done 4900 / 5000 images
# Done 4999 / 5000 images
# Finished preprocessed data to TFRecoeds

# %%
generate_val_data(100, 500)
# Out:
# ../dd2424_project/imagenet_obelisk
# ../dd2424_project/imagenet_palm
# ../dd2424_project/imagenet_cat
# ../dd2424_project/imagenet_shinkansen
# ../dd2424_project/imagenet_people
# panjang file: 500
# Done 100 / 500 images
# Done 200 / 500 images
# Done 300 / 500 images
# Done 400 / 500 images
# Done 500 / 500 images
# Done 500 / 500 images
# Finished preprocessed data to TFRecoeds

# %% [markdown]
# #### Construct the Deep Autoencoder CNN model

# %%
from keras.layers import Conv2D, Input, Reshape, RepeatVector, concatenate, UpSampling2D, Flatten, Conv2DTranspose
from keras.models import Model
from keras.optimizers import Adam

# %%
def y_true_min(yt, yp):
    return K.min(yt)
def y_true_max(yt, yp):
    return K.max(yt)
def y_pred_min(yt, yp):
    return K.min(yp)
def y_pred_max(yt, yp):
    return K.max(yp)

# %%
def gen_model(img_size=128):
    
    # encoder
    encoder_input = Input(shape=(img_size, img_size, 1))
    encoder = Conv2D(64, (3, 3), padding='same', activation='relu', strides=(2,2))(encoder_input)
    encoder = Conv2D(128, (3, 3), padding='same', activation='relu')(encoder)
    encoder = Conv2D(128, (3, 3), padding='same', activation='relu', strides=(2,2))(encoder)
    encoder = Conv2D(256, (3, 3), padding='same', activation='relu')(encoder)
    encoder = Conv2D(256, (3, 3), padding='same', activation='relu', strides=(2,2))(encoder)
    encoder = Conv2D(512, (3, 3), padding='same', activation='relu')(encoder)
    encoder = Conv2D(512, (3, 3), padding='same', activation='relu')(encoder)
    encoder = Conv2D(256, (3, 3), padding='same', activation='relu')(encoder)
    
    # fusion
    batch, height, width, channels = K.int_shape(encoder)
    
    embed_input = Input(shape=(1000,))
    fusion = RepeatVector(height * width)(embed_input)
    fusion = Reshape((height, width, 1000))(fusion)
    fusion = concatenate([encoder, fusion], axis=-1)
    fusion = Conv2D(256, (1, 1), padding='same', activation='relu')(fusion)
    
    # decoder
    decoder = Conv2D(128, (3, 3), padding='same', activation='relu')(fusion)
    decoder = UpSampling2D((2, 2))(decoder)
    decoder = Conv2D(64, (3, 3), padding='same', activation='relu')(decoder)
    decoder = UpSampling2D((2, 2))(decoder)
    decoder = Conv2D(32, (3, 3), padding='same', activation='relu')(decoder)
    decoder = Conv2D(16, (3, 3), padding='same', activation='relu')(decoder)
    decoder = Conv2D(2, (3, 3), padding='same', activation='tanh')(decoder)
    decoder = UpSampling2D((2, 2))(decoder)
    
    model = Model(inputs=[encoder_input, embed_input], outputs=decoder, name='colorizer')
    model.compile(optimizer=Adam(1e-3), loss='mse', metrics=[y_true_max, y_true_min, y_pred_max, y_pred_min])
    
    print("Model built and compiled")
    return model

# %%
model = gen_model()
model.summary()
# Out:
# Model built and compiled
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 64, 64, 64)   640         input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 64, 64, 128)  73856       conv2d_218[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 32, 32, 128)  147584      conv2d_219[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 32, 32, 256)  295168      conv2d_220[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 16, 16, 256)  590080      conv2d_221[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 16, 16, 512)  1180160     conv2d_222[0][0]
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 1000)         0
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 16, 16, 512)  2359808     conv2d_223[0][0]
# __________________________________________________________________________________________________
# repeat_vector_2 (RepeatVector)  (None, 256, 1000)    0           input_5[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 16, 16, 256)  1179904     conv2d_224[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 16, 16, 1000) 0           repeat_vector_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 1256) 0           conv2d_225[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 16, 16, 256)  321792      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 16, 16, 128)  295040      conv2d_226[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 128)  0           conv2d_227[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 32, 32, 64)   73792       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 64)   0           conv2d_228[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 64, 64, 32)   18464       up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 64, 64, 16)   4624        conv2d_229[0][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, 64, 64, 2)    290         conv2d_230[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 128, 128, 2)  0           conv2d_231[0][0]
# ==================================================================================================
# Total params: 6,541,202
# Trainable params: 6,541,202
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Experiment

# %%
# train model
from keras.callbacks import ModelCheckpoint

n_image = 5000
batch_size = 125

tensorboard = TensorBoard(log_dir="./board")
checkpoint = ModelCheckpoint('model_weights_full_imagenet/color_model_5k.h5', monitor='loss', verbose=1, save_best_only=True, save_weights_only=True)
callbacks = [checkpoint, tensorboard]

model.fit_generator(generator=train_generator(batch_size),
                   steps_per_epoch=n_image//batch_size,
                   epochs=150,
                   verbose=1,
                   callbacks=callbacks,
                   validation_data=val_batch_generator(batch_size),
                   validation_steps=1)
# Out:
# Epoch 1/150
# 40/40 [==============================] - 30s 756ms/step - loss: 0.0138 - y_true_max: 0.6969 - y_true_min: -0.6767 - y_pred_max: 0.0290 - y_pred_min: -0.0085 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0583 - val_y_pred_min: -0.0054
#
# Epoch 00001: loss improved from inf to 0.01379, saving model to model_weights_full_imagenet/color_model_5k.h5
# Epoch 2/150
# 40/40 [==============================] - 27s 687ms/step - loss: 0.0130 - y_true_max: 0.6961 - y_true_min: -0.6830 - y_pred_max: 0.0243 - y_pred_min: -0.0095 - val_loss: 0.0160 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0112 - val_y_pred_min: 0.0042
#
# Epoch 00002: loss improved from 0.01379 to 0.01303, saving model to model_weights_full_imagenet/color_model_5k.h5
# Epoch 3/150
# 40/40 [==============================] - 27s 683ms/step - loss: 0.0128 - y_true_max: 0.6964 - y_true_min: -0.6814 - y_pred_max: 0.0131 - y_pred_min: 0.0047 - val_loss: 0.0110 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0116 - val_y_pred_min: 0.0054
#
# Epoch 00003: loss improved from 0.01303 to 0.01284, saving model to model_weights_full_imagenet/color_model_5k.h5
# Epoch 4/150
# 40/40 [==============================] - 27s 679ms/step - loss: 0.0129 - y_true_max: 0.6970 - y_true_min: -0.6811 - y_pred_max: 0.0133 - y_pred_min: 0.0076 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0142 - val_y_pred_min: 0.0070
#
# Epoch 00004: loss did not improve from 0.01284
# Epoch 5/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0128 - y_true_max: 0.6981 - y_true_min: -0.6849 - y_pred_max: 0.0152 - y_pred_min: 0.0084 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0152 - val_y_pred_min: 0.0071
#
# Epoch 00005: loss improved from 0.01284 to 0.01281, saving model to model_weights_full_imagenet/color_model_5k.h5
# Epoch 6/150
# 40/40 [==============================] - 27s 672ms/step - loss: 0.0127 - y_true_max: 0.6971 - y_true_min: -0.6835 - y_pred_max: 0.0147 - y_pred_min: 0.0078 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0150 - val_y_pred_min: 0.0066
#
# Epoch 00006: loss improved from 0.01281 to 0.01274, saving model to model_weights_full_imagenet/color_model_5k.h5
# Epoch 7/150
# 40/40 [==============================] - 27s 670ms/step - loss: 0.0128 - y_true_max: 0.6966 - y_true_min: -0.6766 - y_pred_max: 0.0154 - y_pred_min: 0.0083 - val_loss: 0.0108 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0163 - val_y_pred_min: 0.0087
#
# Epoch 00007: loss did not improve from 0.01274
# Epoch 8/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0131 - y_true_max: 0.6943 - y_true_min: -0.6811 - y_pred_max: 0.0161 - y_pred_min: 0.0083 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0152 - val_y_pred_min: 0.0073
#
# Epoch 00008: loss did not improve from 0.01274
# Epoch 9/150
# 40/40 [==============================] - 27s 672ms/step - loss: 0.0128 - y_true_max: 0.6971 - y_true_min: -0.6836 - y_pred_max: 0.0153 - y_pred_min: 0.0083 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0144 - val_y_pred_min: 0.0065
#
# Epoch 00009: loss did not improve from 0.01274
# Epoch 10/150
# 40/40 [==============================] - 27s 669ms/step - loss: 0.0130 - y_true_max: 0.6970 - y_true_min: -0.6791 - y_pred_max: 0.0152 - y_pred_min: 0.0085 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0149 - val_y_pred_min: 0.0075
#
# Epoch 00010: loss did not improve from 0.01274
# Epoch 11/150
# 40/40 [==============================] - 27s 668ms/step - loss: 0.0127 - y_true_max: 0.6986 - y_true_min: -0.6842 - y_pred_max: 0.0153 - y_pred_min: 0.0080 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0148 - val_y_pred_min: 0.0071
#
# Epoch 00011: loss improved from 0.01274 to 0.01266, saving model to model_weights_full_imagenet/color_model_5k.h5
# Epoch 12/150
# 40/40 [==============================] - 27s 665ms/step - loss: 0.0131 - y_true_max: 0.6940 - y_true_min: -0.6749 - y_pred_max: 0.0146 - y_pred_min: 0.0087 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0156 - val_y_pred_min: 0.0082
#
# Epoch 00012: loss did not improve from 0.01266
# Epoch 13/150
# 40/40 [==============================] - 27s 663ms/step - loss: 0.0128 - y_true_max: 0.6987 - y_true_min: -0.6837 - y_pred_max: 0.0157 - y_pred_min: 0.0079 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0146 - val_y_pred_min: 0.0068
#
# Epoch 00013: loss did not improve from 0.01266
# Epoch 14/150
# 40/40 [==============================] - 27s 665ms/step - loss: 0.0127 - y_true_max: 0.6974 - y_true_min: -0.6763 - y_pred_max: 0.0146 - y_pred_min: 0.0079 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0146 - val_y_pred_min: 0.0077
#
# Epoch 00014: loss did not improve from 0.01266
# Epoch 15/150
# 40/40 [==============================] - 27s 665ms/step - loss: 0.0127 - y_true_max: 0.6978 - y_true_min: -0.6792 - y_pred_max: 0.0146 - y_pred_min: 0.0084 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0150 - val_y_pred_min: 0.0074
#
# Epoch 00015: loss did not improve from 0.01266
# Epoch 16/150
# 40/40 [==============================] - 27s 668ms/step - loss: 0.0128 - y_true_max: 0.6968 - y_true_min: -0.6763 - y_pred_max: 0.0152 - y_pred_min: 0.0083 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0148 - val_y_pred_min: 0.0068
#
# Epoch 00016: loss did not improve from 0.01266
# Epoch 17/150
# 40/40 [==============================] - 27s 674ms/step - loss: 0.0131 - y_true_max: 0.6969 - y_true_min: -0.6798 - y_pred_max: 0.0154 - y_pred_min: 0.0084 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0144 - val_y_pred_min: 0.0071
#
# Epoch 00017: loss did not improve from 0.01266
# Epoch 18/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0129 - y_true_max: 0.6993 - y_true_min: -0.6824 - y_pred_max: 0.0141 - y_pred_min: 0.0081 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0153 - val_y_pred_min: 0.0080
#
# Epoch 00018: loss did not improve from 0.01266
# Epoch 19/150
# 40/40 [==============================] - 27s 669ms/step - loss: 0.0129 - y_true_max: 0.6950 - y_true_min: -0.6785 - y_pred_max: 0.0154 - y_pred_min: 0.0085 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0149 - val_y_pred_min: 0.0066
#
# Epoch 00019: loss did not improve from 0.01266
# Epoch 20/150
# 40/40 [==============================] - 27s 674ms/step - loss: 0.0125 - y_true_max: 0.6974 - y_true_min: -0.6775 - y_pred_max: 0.0157 - y_pred_min: 0.0084 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0152 - val_y_pred_min: 0.0077
#
# Epoch 00020: loss improved from 0.01266 to 0.01254, saving model to model_weights_full_imagenet/color_model_5k.h5
# Epoch 21/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0131 - y_true_max: 0.6974 - y_true_min: -0.6790 - y_pred_max: 0.0153 - y_pred_min: 0.0085 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0145 - val_y_pred_min: 0.0066
#
# Epoch 00021: loss did not improve from 0.01254
# Epoch 22/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0129 - y_true_max: 0.6951 - y_true_min: -0.6740 - y_pred_max: 0.0143 - y_pred_min: 0.0079 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0145 - val_y_pred_min: 0.0069
#
# Epoch 00022: loss did not improve from 0.01254
# Epoch 23/150
# 40/40 [==============================] - 27s 672ms/step - loss: 0.0130 - y_true_max: 0.6974 - y_true_min: -0.6757 - y_pred_max: 0.0156 - y_pred_min: 0.0088 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0156 - val_y_pred_min: 0.0070
#
# Epoch 00023: loss did not improve from 0.01254
# Epoch 24/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0126 - y_true_max: 0.6981 - y_true_min: -0.6744 - y_pred_max: 0.0147 - y_pred_min: 0.0078 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0145 - val_y_pred_min: 0.0066
#
# Epoch 00024: loss did not improve from 0.01254
# Epoch 25/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0130 - y_true_max: 0.6960 - y_true_min: -0.6767 - y_pred_max: 0.0150 - y_pred_min: 0.0083 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0155 - val_y_pred_min: 0.0076
#
# Epoch 00025: loss did not improve from 0.01254
# Epoch 26/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0128 - y_true_max: 0.6975 - y_true_min: -0.6719 - y_pred_max: 0.0156 - y_pred_min: 0.0090 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0155 - val_y_pred_min: 0.0073
#
# Epoch 00026: loss did not improve from 0.01254
# Epoch 27/150
# 40/40 [==============================] - 27s 665ms/step - loss: 0.0130 - y_true_max: 0.6983 - y_true_min: -0.6781 - y_pred_max: 0.0153 - y_pred_min: 0.0079 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0154 - val_y_pred_min: 0.0077
#
# Epoch 00027: loss did not improve from 0.01254
# Epoch 28/150
# 40/40 [==============================] - 27s 666ms/step - loss: 0.0125 - y_true_max: 0.6961 - y_true_min: -0.6723 - y_pred_max: 0.0139 - y_pred_min: 0.0077 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0144 - val_y_pred_min: 0.0067
#
# Epoch 00028: loss improved from 0.01254 to 0.01250, saving model to model_weights_full_imagenet/color_model_5k.h5
# Epoch 29/150
# 40/40 [==============================] - 27s 666ms/step - loss: 0.0131 - y_true_max: 0.6958 - y_true_min: -0.6702 - y_pred_max: 0.0154 - y_pred_min: 0.0088 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0152 - val_y_pred_min: 0.0069
#
# Epoch 00029: loss did not improve from 0.01250
# Epoch 30/150
# 40/40 [==============================] - 27s 664ms/step - loss: 0.0129 - y_true_max: 0.6968 - y_true_min: -0.6786 - y_pred_max: 0.0152 - y_pred_min: 0.0078 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0147 - val_y_pred_min: 0.0068
#
# Epoch 00030: loss did not improve from 0.01250
# Epoch 31/150
# 40/40 [==============================] - 27s 664ms/step - loss: 0.0129 - y_true_max: 0.6955 - y_true_min: -0.6770 - y_pred_max: 0.0151 - y_pred_min: 0.0085 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0145 - val_y_pred_min: 0.0067
#
# Epoch 00031: loss did not improve from 0.01250
# Epoch 32/150
# 40/40 [==============================] - 27s 670ms/step - loss: 0.0129 - y_true_max: 0.6950 - y_true_min: -0.6697 - y_pred_max: 0.0154 - y_pred_min: 0.0083 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0149 - val_y_pred_min: 0.0076
#
# Epoch 00032: loss did not improve from 0.01250
# Epoch 33/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0129 - y_true_max: 0.6941 - y_true_min: -0.6764 - y_pred_max: 0.0156 - y_pred_min: 0.0086 - val_loss: 0.0108 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0157 - val_y_pred_min: 0.0077
#
# Epoch 00033: loss did not improve from 0.01250
# Epoch 34/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0126 - y_true_max: 0.6954 - y_true_min: -0.6726 - y_pred_max: 0.0148 - y_pred_min: 0.0078 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0144 - val_y_pred_min: 0.0064
#
# Epoch 00034: loss did not improve from 0.01250
# Epoch 35/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0131 - y_true_max: 0.6968 - y_true_min: -0.6751 - y_pred_max: 0.0144 - y_pred_min: 0.0081 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0147 - val_y_pred_min: 0.0076
#
# Epoch 00035: loss did not improve from 0.01250
# Epoch 36/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0127 - y_true_max: 0.6961 - y_true_min: -0.6736 - y_pred_max: 0.0157 - y_pred_min: 0.0090 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0155 - val_y_pred_min: 0.0075
#
# Epoch 00036: loss did not improve from 0.01250
# Epoch 37/150
# 40/40 [==============================] - 27s 674ms/step - loss: 0.0128 - y_true_max: 0.6953 - y_true_min: -0.6745 - y_pred_max: 0.0146 - y_pred_min: 0.0077 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0144 - val_y_pred_min: 0.0069
#
# Epoch 00037: loss did not improve from 0.01250
# Epoch 38/150
# 40/40 [==============================] - 27s 674ms/step - loss: 0.0130 - y_true_max: 0.6930 - y_true_min: -0.6687 - y_pred_max: 0.0149 - y_pred_min: 0.0085 - val_loss: 0.0153 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0155 - val_y_pred_min: 0.0083
#
# Epoch 00038: loss did not improve from 0.01250
# Epoch 39/150
# 40/40 [==============================] - 27s 674ms/step - loss: 0.0127 - y_true_max: 0.6987 - y_true_min: -0.6784 - y_pred_max: 0.0153 - y_pred_min: 0.0081 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0150 - val_y_pred_min: 0.0074
#
# Epoch 00039: loss did not improve from 0.01250
# Epoch 40/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0133 - y_true_max: 0.6946 - y_true_min: -0.6669 - y_pred_max: 0.0150 - y_pred_min: 0.0085 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0155 - val_y_pred_min: 0.0081
#
# Epoch 00040: loss did not improve from 0.01250
# Epoch 41/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0125 - y_true_max: 0.6985 - y_true_min: -0.6808 - y_pred_max: 0.0148 - y_pred_min: 0.0081 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0147 - val_y_pred_min: 0.0062
#
# Epoch 00041: loss improved from 0.01250 to 0.01250, saving model to model_weights_full_imagenet/color_model_5k.h5
# Epoch 42/150
# 40/40 [==============================] - 27s 670ms/step - loss: 0.0131 - y_true_max: 0.6938 - y_true_min: -0.6679 - y_pred_max: 0.0155 - y_pred_min: 0.0085 - val_loss: 0.0153 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0158 - val_y_pred_min: 0.0083
#
# Epoch 00042: loss did not improve from 0.01250
# Epoch 43/150
# 40/40 [==============================] - 27s 674ms/step - loss: 0.0126 - y_true_max: 0.6974 - y_true_min: -0.6763 - y_pred_max: 0.0151 - y_pred_min: 0.0082 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0144 - val_y_pred_min: 0.0068
#
# Epoch 00043: loss did not improve from 0.01250
# Epoch 44/150
# 40/40 [==============================] - 27s 674ms/step - loss: 0.0129 - y_true_max: 0.6930 - y_true_min: -0.6688 - y_pred_max: 0.0153 - y_pred_min: 0.0082 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0150 - val_y_pred_min: 0.0071
#
# Epoch 00044: loss did not improve from 0.01250
# Epoch 45/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0131 - y_true_max: 0.6982 - y_true_min: -0.6738 - y_pred_max: 0.0145 - y_pred_min: 0.0084 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0152 - val_y_pred_min: 0.0078
#
# Epoch 00045: loss did not improve from 0.01250
# Epoch 46/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0128 - y_true_max: 0.6963 - y_true_min: -0.6787 - y_pred_max: 0.0152 - y_pred_min: 0.0084 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0148 - val_y_pred_min: 0.0071
#
# Epoch 00046: loss did not improve from 0.01250
# Epoch 47/150
# 40/40 [==============================] - 27s 669ms/step - loss: 0.0127 - y_true_max: 0.6965 - y_true_min: -0.6731 - y_pred_max: 0.0148 - y_pred_min: 0.0079 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0151 - val_y_pred_min: 0.0069
#
# Epoch 00047: loss did not improve from 0.01250
# Epoch 48/150
# 40/40 [==============================] - 27s 670ms/step - loss: 0.0128 - y_true_max: 0.6941 - y_true_min: -0.6745 - y_pred_max: 0.0153 - y_pred_min: 0.0085 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0146 - val_y_pred_min: 0.0071
#
# Epoch 00048: loss did not improve from 0.01250
# Epoch 49/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0129 - y_true_max: 0.6969 - y_true_min: -0.6730 - y_pred_max: 0.0155 - y_pred_min: 0.0083 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0155 - val_y_pred_min: 0.0066
#
# Epoch 00049: loss did not improve from 0.01250
# Epoch 50/150
# 40/40 [==============================] - 27s 666ms/step - loss: 0.0129 - y_true_max: 0.6942 - y_true_min: -0.6724 - y_pred_max: 0.0148 - y_pred_min: 0.0082 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0143 - val_y_pred_min: 0.0072
#
# Epoch 00050: loss did not improve from 0.01250
# Epoch 51/150
# 40/40 [==============================] - 27s 668ms/step - loss: 0.0128 - y_true_max: 0.6953 - y_true_min: -0.6750 - y_pred_max: 0.0151 - y_pred_min: 0.0082 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0147 - val_y_pred_min: 0.0065
#
# Epoch 00051: loss did not improve from 0.01250
# Epoch 52/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0128 - y_true_max: 0.6964 - y_true_min: -0.6763 - y_pred_max: 0.0150 - y_pred_min: 0.0085 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0145 - val_y_pred_min: 0.0067
#
# Epoch 00052: loss did not improve from 0.01250
# Epoch 53/150
# 40/40 [==============================] - 27s 666ms/step - loss: 0.0128 - y_true_max: 0.6962 - y_true_min: -0.6707 - y_pred_max: 0.0151 - y_pred_min: 0.0082 - val_loss: 0.0108 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0162 - val_y_pred_min: 0.0088
#
# Epoch 00053: loss did not improve from 0.01250
# Epoch 54/150
# 40/40 [==============================] - 27s 666ms/step - loss: 0.0129 - y_true_max: 0.6963 - y_true_min: -0.6744 - y_pred_max: 0.0150 - y_pred_min: 0.0082 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0142 - val_y_pred_min: 0.0057
#
# Epoch 00054: loss did not improve from 0.01250
# Epoch 55/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0130 - y_true_max: 0.6968 - y_true_min: -0.6719 - y_pred_max: 0.0151 - y_pred_min: 0.0084 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0153 - val_y_pred_min: 0.0077
#
# Epoch 00055: loss did not improve from 0.01250
# Epoch 56/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0129 - y_true_max: 0.6957 - y_true_min: -0.6725 - y_pred_max: 0.0152 - y_pred_min: 0.0086 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0151 - val_y_pred_min: 0.0067
#
# Epoch 00056: loss did not improve from 0.01250
# Epoch 57/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0125 - y_true_max: 0.6941 - y_true_min: -0.6746 - y_pred_max: 0.0148 - y_pred_min: 0.0076 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0142 - val_y_pred_min: 0.0065
#
# Epoch 00057: loss did not improve from 0.01250
# Epoch 58/150
# 40/40 [==============================] - 27s 665ms/step - loss: 0.0130 - y_true_max: 0.6960 - y_true_min: -0.6711 - y_pred_max: 0.0146 - y_pred_min: 0.0086 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0152 - val_y_pred_min: 0.0074
#
# Epoch 00058: loss did not improve from 0.01250
# Epoch 59/150
# 40/40 [==============================] - 27s 666ms/step - loss: 0.0132 - y_true_max: 0.6972 - y_true_min: -0.6754 - y_pred_max: 0.0158 - y_pred_min: 0.0087 - val_loss: 0.0108 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0161 - val_y_pred_min: 0.0087
#
# Epoch 00059: loss did not improve from 0.01250
# Epoch 60/150
# 40/40 [==============================] - 27s 666ms/step - loss: 0.0126 - y_true_max: 0.6933 - y_true_min: -0.6729 - y_pred_max: 0.0151 - y_pred_min: 0.0078 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0143 - val_y_pred_min: 0.0061
#
# Epoch 00060: loss did not improve from 0.01250
# Epoch 61/150
# 40/40 [==============================] - 27s 666ms/step - loss: 0.0129 - y_true_max: 0.6938 - y_true_min: -0.6752 - y_pred_max: 0.0146 - y_pred_min: 0.0084 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0155 - val_y_pred_min: 0.0085
#
# Epoch 00061: loss did not improve from 0.01250
# Epoch 62/150
# 40/40 [==============================] - 27s 668ms/step - loss: 0.0128 - y_true_max: 0.6998 - y_true_min: -0.6734 - y_pred_max: 0.0142 - y_pred_min: 0.0074 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0149 - val_y_pred_min: 0.0076
#
# Epoch 00062: loss did not improve from 0.01250
# Epoch 63/150
# 40/40 [==============================] - 27s 674ms/step - loss: 0.0130 - y_true_max: 0.6940 - y_true_min: -0.6713 - y_pred_max: 0.0159 - y_pred_min: 0.0094 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0159 - val_y_pred_min: 0.0075
#
# Epoch 00063: loss did not improve from 0.01250
# Epoch 64/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0130 - y_true_max: 0.6922 - y_true_min: -0.6722 - y_pred_max: 0.0155 - y_pred_min: 0.0081 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0158 - val_y_pred_min: 0.0079
#
# Epoch 00064: loss did not improve from 0.01250
# Epoch 65/150
# 40/40 [==============================] - 27s 664ms/step - loss: 0.0126 - y_true_max: 0.6957 - y_true_min: -0.6758 - y_pred_max: 0.0150 - y_pred_min: 0.0081 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0145 - val_y_pred_min: 0.0068
#
# Epoch 00065: loss did not improve from 0.01250
# Epoch 66/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0128 - y_true_max: 0.6964 - y_true_min: -0.6683 - y_pred_max: 0.0145 - y_pred_min: 0.0083 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0152 - val_y_pred_min: 0.0077
#
# Epoch 00066: loss did not improve from 0.01250
# Epoch 67/150
# 40/40 [==============================] - 27s 666ms/step - loss: 0.0129 - y_true_max: 0.6951 - y_true_min: -0.6787 - y_pred_max: 0.0158 - y_pred_min: 0.0085 - val_loss: 0.0153 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0155 - val_y_pred_min: 0.0075
#
# Epoch 00067: loss did not improve from 0.01250
# Epoch 68/150
# 40/40 [==============================] - 27s 665ms/step - loss: 0.0128 - y_true_max: 0.6954 - y_true_min: -0.6729 - y_pred_max: 0.0153 - y_pred_min: 0.0086 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0153 - val_y_pred_min: 0.0074
#
# Epoch 00068: loss did not improve from 0.01250
# Epoch 69/150
# 40/40 [==============================] - 27s 664ms/step - loss: 0.0128 - y_true_max: 0.6960 - y_true_min: -0.6721 - y_pred_max: 0.0147 - y_pred_min: 0.0075 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0143 - val_y_pred_min: 0.0069
#
# Epoch 00069: loss did not improve from 0.01250
# Epoch 70/150
# 40/40 [==============================] - 27s 664ms/step - loss: 0.0128 - y_true_max: 0.6977 - y_true_min: -0.6752 - y_pred_max: 0.0146 - y_pred_min: 0.0087 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0150 - val_y_pred_min: 0.0073
#
# Epoch 00070: loss did not improve from 0.01250
# Epoch 71/150
# 40/40 [==============================] - 27s 665ms/step - loss: 0.0128 - y_true_max: 0.6981 - y_true_min: -0.6729 - y_pred_max: 0.0150 - y_pred_min: 0.0082 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0154 - val_y_pred_min: 0.0072
#
# Epoch 00071: loss did not improve from 0.01250
# Epoch 72/150
# 40/40 [==============================] - 27s 664ms/step - loss: 0.0129 - y_true_max: 0.6968 - y_true_min: -0.6743 - y_pred_max: 0.0153 - y_pred_min: 0.0085 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0152 - val_y_pred_min: 0.0070
#
# Epoch 00072: loss did not improve from 0.01250
# Epoch 73/150
# 40/40 [==============================] - 27s 664ms/step - loss: 0.0128 - y_true_max: 0.6980 - y_true_min: -0.6744 - y_pred_max: 0.0152 - y_pred_min: 0.0082 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0152 - val_y_pred_min: 0.0069
#
# Epoch 00073: loss did not improve from 0.01250
# Epoch 74/150
# 40/40 [==============================] - 27s 670ms/step - loss: 0.0129 - y_true_max: 0.6960 - y_true_min: -0.6772 - y_pred_max: 0.0145 - y_pred_min: 0.0081 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0150 - val_y_pred_min: 0.0075
#
# Epoch 00074: loss did not improve from 0.01250
# Epoch 75/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0130 - y_true_max: 0.6983 - y_true_min: -0.6799 - y_pred_max: 0.0156 - y_pred_min: 0.0088 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0161 - val_y_pred_min: 0.0075
#
# Epoch 00075: loss did not improve from 0.01250
# Epoch 76/150
# 40/40 [==============================] - 27s 672ms/step - loss: 0.0126 - y_true_max: 0.6963 - y_true_min: -0.6837 - y_pred_max: 0.0155 - y_pred_min: 0.0079 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0147 - val_y_pred_min: 0.0071
#
# Epoch 00076: loss did not improve from 0.01250
# Epoch 77/150
# 40/40 [==============================] - 27s 668ms/step - loss: 0.0129 - y_true_max: 0.7002 - y_true_min: -0.6790 - y_pred_max: 0.0147 - y_pred_min: 0.0081 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0150 - val_y_pred_min: 0.0069
#
# Epoch 00077: loss did not improve from 0.01250
# Epoch 78/150
# 40/40 [==============================] - 27s 670ms/step - loss: 0.0129 - y_true_max: 0.6963 - y_true_min: -0.6723 - y_pred_max: 0.0139 - y_pred_min: 0.0081 - val_loss: 0.0158 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0161 - val_y_pred_min: 0.0090
#
# Epoch 00078: loss did not improve from 0.01250
# Epoch 79/150
# 40/40 [==============================] - 27s 669ms/step - loss: 0.0131 - y_true_max: 0.7003 - y_true_min: -0.6824 - y_pred_max: 0.0160 - y_pred_min: 0.0090 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0161 - val_y_pred_min: 0.0074
#
# Epoch 00079: loss did not improve from 0.01250
# Epoch 80/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0125 - y_true_max: 0.6979 - y_true_min: -0.6772 - y_pred_max: 0.0154 - y_pred_min: 0.0082 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0158 - val_y_pred_min: 0.0083
#
# Epoch 00080: loss did not improve from 0.01250
# Epoch 81/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0128 - y_true_max: 0.6977 - y_true_min: -0.6781 - y_pred_max: 0.0148 - y_pred_min: 0.0080 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0143 - val_y_pred_min: 0.0065
#
# Epoch 00081: loss did not improve from 0.01250
# Epoch 82/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0128 - y_true_max: 0.6968 - y_true_min: -0.6756 - y_pred_max: 0.0149 - y_pred_min: 0.0085 - val_loss: 0.0153 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0155 - val_y_pred_min: 0.0075
#
# Epoch 00082: loss did not improve from 0.01250
# Epoch 83/150
# 40/40 [==============================] - 27s 665ms/step - loss: 0.0129 - y_true_max: 0.6950 - y_true_min: -0.6783 - y_pred_max: 0.0150 - y_pred_min: 0.0083 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0154 - val_y_pred_min: 0.0072
#
# Epoch 00083: loss did not improve from 0.01250
# Epoch 84/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0130 - y_true_max: 0.6965 - y_true_min: -0.6811 - y_pred_max: 0.0153 - y_pred_min: 0.0082 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0155 - val_y_pred_min: 0.0074
#
# Epoch 00084: loss did not improve from 0.01250
# Epoch 85/150
# 40/40 [==============================] - 27s 672ms/step - loss: 0.0127 - y_true_max: 0.6975 - y_true_min: -0.6793 - y_pred_max: 0.0153 - y_pred_min: 0.0082 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0148 - val_y_pred_min: 0.0069
#
# Epoch 00085: loss did not improve from 0.01250
# Epoch 86/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0128 - y_true_max: 0.6960 - y_true_min: -0.6809 - y_pred_max: 0.0150 - y_pred_min: 0.0085 - val_loss: 0.0153 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0154 - val_y_pred_min: 0.0079
#
# Epoch 00086: loss did not improve from 0.01250
# Epoch 87/150
# 40/40 [==============================] - 27s 672ms/step - loss: 0.0130 - y_true_max: 0.6957 - y_true_min: -0.6779 - y_pred_max: 0.0146 - y_pred_min: 0.0082 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0159 - val_y_pred_min: 0.0078
#
# Epoch 00087: loss did not improve from 0.01250
# Epoch 88/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0130 - y_true_max: 0.6953 - y_true_min: -0.6789 - y_pred_max: 0.0152 - y_pred_min: 0.0082 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0156 - val_y_pred_min: 0.0081
#
# Epoch 00088: loss did not improve from 0.01250
# Epoch 89/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0126 - y_true_max: 0.6968 - y_true_min: -0.6797 - y_pred_max: 0.0149 - y_pred_min: 0.0084 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0159 - val_y_pred_min: 0.0076
#
# Epoch 00089: loss did not improve from 0.01250
# Epoch 90/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0129 - y_true_max: 0.6969 - y_true_min: -0.6748 - y_pred_max: 0.0146 - y_pred_min: 0.0079 - val_loss: 0.0108 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0155 - val_y_pred_min: 0.0081
#
# Epoch 00090: loss did not improve from 0.01250
# Epoch 91/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0129 - y_true_max: 0.6991 - y_true_min: -0.6708 - y_pred_max: 0.0149 - y_pred_min: 0.0084 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0158 - val_y_pred_min: 0.0071
#
# Epoch 00091: loss did not improve from 0.01250
# Epoch 92/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0129 - y_true_max: 0.6980 - y_true_min: -0.6771 - y_pred_max: 0.0157 - y_pred_min: 0.0082 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0154 - val_y_pred_min: 0.0075
#
# Epoch 00092: loss did not improve from 0.01250
# Epoch 93/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0128 - y_true_max: 0.6992 - y_true_min: -0.6751 - y_pred_max: 0.0155 - y_pred_min: 0.0087 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0159 - val_y_pred_min: 0.0075
#
# Epoch 00093: loss did not improve from 0.01250
# Epoch 94/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0128 - y_true_max: 0.6973 - y_true_min: -0.6763 - y_pred_max: 0.0151 - y_pred_min: 0.0080 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0150 - val_y_pred_min: 0.0073
#
# Epoch 00094: loss did not improve from 0.01250
# Epoch 95/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0131 - y_true_max: 0.6979 - y_true_min: -0.6743 - y_pred_max: 0.0148 - y_pred_min: 0.0081 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0152 - val_y_pred_min: 0.0075
#
# Epoch 00095: loss did not improve from 0.01250
# Epoch 96/150
# 40/40 [==============================] - 27s 672ms/step - loss: 0.0127 - y_true_max: 0.6985 - y_true_min: -0.6687 - y_pred_max: 0.0150 - y_pred_min: 0.0087 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0151 - val_y_pred_min: 0.0074
#
# Epoch 00096: loss did not improve from 0.01250
# Epoch 97/150
# 40/40 [==============================] - 27s 674ms/step - loss: 0.0128 - y_true_max: 0.6983 - y_true_min: -0.6738 - y_pred_max: 0.0149 - y_pred_min: 0.0079 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0152 - val_y_pred_min: 0.0071
#
# Epoch 00097: loss did not improve from 0.01250
# Epoch 98/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0132 - y_true_max: 0.6975 - y_true_min: -0.6771 - y_pred_max: 0.0152 - y_pred_min: 0.0086 - val_loss: 0.0153 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0159 - val_y_pred_min: 0.0082
#
# Epoch 00098: loss did not improve from 0.01250
# Epoch 99/150
# 40/40 [==============================] - 27s 672ms/step - loss: 0.0125 - y_true_max: 0.6996 - y_true_min: -0.6649 - y_pred_max: 0.0153 - y_pred_min: 0.0083 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0146 - val_y_pred_min: 0.0056
#
# Epoch 00099: loss improved from 0.01250 to 0.01245, saving model to model_weights_full_imagenet/color_model_5k.h5
# Epoch 100/150
# 40/40 [==============================] - 27s 664ms/step - loss: 0.0129 - y_true_max: 0.6982 - y_true_min: -0.6760 - y_pred_max: 0.0160 - y_pred_min: 0.0083 - val_loss: 0.0158 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0166 - val_y_pred_min: 0.0075
#
# Epoch 00100: loss did not improve from 0.01245
# Epoch 101/150
# 40/40 [==============================] - 27s 668ms/step - loss: 0.0128 - y_true_max: 0.6998 - y_true_min: -0.6750 - y_pred_max: 0.0147 - y_pred_min: 0.0081 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0140 - val_y_pred_min: 0.0065
#
# Epoch 00101: loss did not improve from 0.01245
# Epoch 102/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0131 - y_true_max: 0.6980 - y_true_min: -0.6707 - y_pred_max: 0.0138 - y_pred_min: 0.0082 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0157 - val_y_pred_min: 0.0082
#
# Epoch 00102: loss did not improve from 0.01245
# Epoch 103/150
# 40/40 [==============================] - 27s 666ms/step - loss: 0.0127 - y_true_max: 0.6969 - y_true_min: -0.6775 - y_pred_max: 0.0158 - y_pred_min: 0.0089 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0167 - val_y_pred_min: 0.0085
#
# Epoch 00103: loss did not improve from 0.01245
# Epoch 104/150
# 40/40 [==============================] - 27s 666ms/step - loss: 0.0127 - y_true_max: 0.6992 - y_true_min: -0.6680 - y_pred_max: 0.0156 - y_pred_min: 0.0085 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0159 - val_y_pred_min: 0.0075
#
# Epoch 00104: loss did not improve from 0.01245
# Epoch 105/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0132 - y_true_max: 0.6992 - y_true_min: -0.6706 - y_pred_max: 0.0146 - y_pred_min: 0.0074 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0148 - val_y_pred_min: 0.0077
#
# Epoch 00105: loss did not improve from 0.01245
# Epoch 106/150
# 40/40 [==============================] - 27s 672ms/step - loss: 0.0127 - y_true_max: 0.6965 - y_true_min: -0.6723 - y_pred_max: 0.0151 - y_pred_min: 0.0087 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0150 - val_y_pred_min: 0.0073
#
# Epoch 00106: loss did not improve from 0.01245
# Epoch 107/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0131 - y_true_max: 0.6994 - y_true_min: -0.6744 - y_pred_max: 0.0155 - y_pred_min: 0.0080 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0155 - val_y_pred_min: 0.0078
#
# Epoch 00107: loss did not improve from 0.01245
# Epoch 108/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0127 - y_true_max: 0.6984 - y_true_min: -0.6742 - y_pred_max: 0.0148 - y_pred_min: 0.0087 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0149 - val_y_pred_min: 0.0069
#
# Epoch 00108: loss did not improve from 0.01245
# Epoch 109/150
# 40/40 [==============================] - 27s 674ms/step - loss: 0.0127 - y_true_max: 0.6963 - y_true_min: -0.6709 - y_pred_max: 0.0150 - y_pred_min: 0.0084 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0151 - val_y_pred_min: 0.0072
#
# Epoch 00109: loss did not improve from 0.01245
# Epoch 110/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0128 - y_true_max: 0.6985 - y_true_min: -0.6733 - y_pred_max: 0.0150 - y_pred_min: 0.0079 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0146 - val_y_pred_min: 0.0059
#
# Epoch 00110: loss did not improve from 0.01245
# Epoch 111/150
# 40/40 [==============================] - 27s 670ms/step - loss: 0.0129 - y_true_max: 0.6959 - y_true_min: -0.6806 - y_pred_max: 0.0143 - y_pred_min: 0.0076 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0144 - val_y_pred_min: 0.0073
#
# Epoch 00111: loss did not improve from 0.01245
# Epoch 112/150
# 40/40 [==============================] - 27s 670ms/step - loss: 0.0131 - y_true_max: 0.7006 - y_true_min: -0.6713 - y_pred_max: 0.0155 - y_pred_min: 0.0093 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0160 - val_y_pred_min: 0.0078
#
# Epoch 00112: loss did not improve from 0.01245
# Epoch 113/150
# 40/40 [==============================] - 27s 670ms/step - loss: 0.0126 - y_true_max: 0.6957 - y_true_min: -0.6832 - y_pred_max: 0.0151 - y_pred_min: 0.0081 - val_loss: 0.0108 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0161 - val_y_pred_min: 0.0081
#
# Epoch 00113: loss did not improve from 0.01245
# Epoch 114/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0129 - y_true_max: 0.7016 - y_true_min: -0.6763 - y_pred_max: 0.0154 - y_pred_min: 0.0082 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0146 - val_y_pred_min: 0.0068
#
# Epoch 00114: loss did not improve from 0.01245
# Epoch 115/150
# 40/40 [==============================] - 27s 669ms/step - loss: 0.0129 - y_true_max: 0.6965 - y_true_min: -0.6778 - y_pred_max: 0.0151 - y_pred_min: 0.0081 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0152 - val_y_pred_min: 0.0079
#
# Epoch 00115: loss did not improve from 0.01245
# Epoch 116/150
# 40/40 [==============================] - 27s 670ms/step - loss: 0.0128 - y_true_max: 0.6973 - y_true_min: -0.6757 - y_pred_max: 0.0151 - y_pred_min: 0.0085 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0151 - val_y_pred_min: 0.0071
#
# Epoch 00116: loss did not improve from 0.01245
# Epoch 117/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0129 - y_true_max: 0.6962 - y_true_min: -0.6748 - y_pred_max: 0.0146 - y_pred_min: 0.0079 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0147 - val_y_pred_min: 0.0068
#
# Epoch 00117: loss did not improve from 0.01245
# Epoch 118/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0129 - y_true_max: 0.6982 - y_true_min: -0.6808 - y_pred_max: 0.0151 - y_pred_min: 0.0084 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0147 - val_y_pred_min: 0.0064
#
# Epoch 00118: loss did not improve from 0.01245
# Epoch 119/150
# 40/40 [==============================] - 27s 670ms/step - loss: 0.0129 - y_true_max: 0.6950 - y_true_min: -0.6759 - y_pred_max: 0.0142 - y_pred_min: 0.0078 - val_loss: 0.0153 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0156 - val_y_pred_min: 0.0086
#
# Epoch 00119: loss did not improve from 0.01245
# Epoch 120/150
# 40/40 [==============================] - 27s 670ms/step - loss: 0.0128 - y_true_max: 0.6979 - y_true_min: -0.6829 - y_pred_max: 0.0160 - y_pred_min: 0.0096 - val_loss: 0.0153 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0163 - val_y_pred_min: 0.0075
#
# Epoch 00120: loss did not improve from 0.01245
# Epoch 121/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0129 - y_true_max: 0.6974 - y_true_min: -0.6796 - y_pred_max: 0.0151 - y_pred_min: 0.0076 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0147 - val_y_pred_min: 0.0073
#
# Epoch 00121: loss did not improve from 0.01245
# Epoch 122/150
# 40/40 [==============================] - 27s 670ms/step - loss: 0.0127 - y_true_max: 0.6949 - y_true_min: -0.6752 - y_pred_max: 0.0146 - y_pred_min: 0.0083 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0149 - val_y_pred_min: 0.0068
#
# Epoch 00122: loss did not improve from 0.01245
# Epoch 123/150
# 40/40 [==============================] - 27s 666ms/step - loss: 0.0129 - y_true_max: 0.6968 - y_true_min: -0.6778 - y_pred_max: 0.0146 - y_pred_min: 0.0081 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0154 - val_y_pred_min: 0.0070
#
# Epoch 00123: loss did not improve from 0.01245
# Epoch 124/150
# 40/40 [==============================] - 27s 670ms/step - loss: 0.0130 - y_true_max: 0.6974 - y_true_min: -0.6829 - y_pred_max: 0.0157 - y_pred_min: 0.0085 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0154 - val_y_pred_min: 0.0072
#
# Epoch 00124: loss did not improve from 0.01245
# Epoch 125/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0126 - y_true_max: 0.6958 - y_true_min: -0.6745 - y_pred_max: 0.0149 - y_pred_min: 0.0089 - val_loss: 0.0108 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0158 - val_y_pred_min: 0.0076
#
# Epoch 00125: loss did not improve from 0.01245
# Epoch 126/150
# 40/40 [==============================] - 27s 672ms/step - loss: 0.0131 - y_true_max: 0.7002 - y_true_min: -0.6824 - y_pred_max: 0.0151 - y_pred_min: 0.0074 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0154 - val_y_pred_min: 0.0073
#
# Epoch 00126: loss did not improve from 0.01245
# Epoch 127/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0129 - y_true_max: 0.6924 - y_true_min: -0.6777 - y_pred_max: 0.0153 - y_pred_min: 0.0091 - val_loss: 0.0153 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0163 - val_y_pred_min: 0.0081
#
# Epoch 00127: loss did not improve from 0.01245
# Epoch 128/150
# 40/40 [==============================] - 27s 665ms/step - loss: 0.0126 - y_true_max: 0.6983 - y_true_min: -0.6828 - y_pred_max: 0.0156 - y_pred_min: 0.0078 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0150 - val_y_pred_min: 0.0063
#
# Epoch 00128: loss did not improve from 0.01245
# Epoch 129/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0131 - y_true_max: 0.6986 - y_true_min: -0.6847 - y_pred_max: 0.0150 - y_pred_min: 0.0086 - val_loss: 0.0153 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0158 - val_y_pred_min: 0.0083
#
# Epoch 00129: loss did not improve from 0.01245
# Epoch 130/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0128 - y_true_max: 0.6962 - y_true_min: -0.6773 - y_pred_max: 0.0151 - y_pred_min: 0.0082 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0148 - val_y_pred_min: 0.0069
#
# Epoch 00130: loss did not improve from 0.01245
# Epoch 131/150
# 40/40 [==============================] - 27s 672ms/step - loss: 0.0130 - y_true_max: 0.6959 - y_true_min: -0.6845 - y_pred_max: 0.0148 - y_pred_min: 0.0079 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0151 - val_y_pred_min: 0.0074
#
# Epoch 00131: loss did not improve from 0.01245
# Epoch 132/150
# 40/40 [==============================] - 27s 672ms/step - loss: 0.0127 - y_true_max: 0.6957 - y_true_min: -0.6833 - y_pred_max: 0.0147 - y_pred_min: 0.0086 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0156 - val_y_pred_min: 0.0077
#
# Epoch 00132: loss did not improve from 0.01245
# Epoch 133/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0128 - y_true_max: 0.6987 - y_true_min: -0.6814 - y_pred_max: 0.0152 - y_pred_min: 0.0080 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0147 - val_y_pred_min: 0.0064
#
# Epoch 00133: loss did not improve from 0.01245
# Epoch 134/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0131 - y_true_max: 0.6956 - y_true_min: -0.6805 - y_pred_max: 0.0153 - y_pred_min: 0.0083 - val_loss: 0.0153 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0160 - val_y_pred_min: 0.0081
#
# Epoch 00134: loss did not improve from 0.01245
# Epoch 135/150
# 40/40 [==============================] - 27s 663ms/step - loss: 0.0128 - y_true_max: 0.6969 - y_true_min: -0.6807 - y_pred_max: 0.0153 - y_pred_min: 0.0090 - val_loss: 0.0108 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0160 - val_y_pred_min: 0.0077
#
# Epoch 00135: loss did not improve from 0.01245
# Epoch 136/150
# 40/40 [==============================] - 27s 665ms/step - loss: 0.0126 - y_true_max: 0.6980 - y_true_min: -0.6779 - y_pred_max: 0.0146 - y_pred_min: 0.0070 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0140 - val_y_pred_min: 0.0058
#
# Epoch 00136: loss did not improve from 0.01245
# Epoch 137/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0130 - y_true_max: 0.6962 - y_true_min: -0.6783 - y_pred_max: 0.0151 - y_pred_min: 0.0086 - val_loss: 0.0109 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0153 - val_y_pred_min: 0.0082
#
# Epoch 00137: loss did not improve from 0.01245
# Epoch 138/150
# 40/40 [==============================] - 27s 671ms/step - loss: 0.0128 - y_true_max: 0.6969 - y_true_min: -0.6810 - y_pred_max: 0.0148 - y_pred_min: 0.0085 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0149 - val_y_pred_min: 0.0063
#
# Epoch 00138: loss did not improve from 0.01245
# Epoch 139/150
# 40/40 [==============================] - 27s 673ms/step - loss: 0.0131 - y_true_max: 0.6963 - y_true_min: -0.6819 - y_pred_max: 0.0152 - y_pred_min: 0.0082 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0156 - val_y_pred_min: 0.0079
#
# Epoch 00139: loss did not improve from 0.01245
# Epoch 140/150
# 40/40 [==============================] - 27s 669ms/step - loss: 0.0126 - y_true_max: 0.6971 - y_true_min: -0.6770 - y_pred_max: 0.0151 - y_pred_min: 0.0085 - val_loss: 0.0159 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0154 - val_y_pred_min: 0.0068
#
# Epoch 00140: loss did not improve from 0.01245
# Epoch 141/150
# 40/40 [==============================] - 27s 666ms/step - loss: 0.0126 - y_true_max: 0.6988 - y_true_min: -0.6726 - y_pred_max: 0.0156 - y_pred_min: 0.0083 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0162 - val_y_pred_min: 0.0078
#
# Epoch 00141: loss did not improve from 0.01245
# Epoch 142/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0133 - y_true_max: 0.6951 - y_true_min: -0.6840 - y_pred_max: 0.0149 - y_pred_min: 0.0084 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0150 - val_y_pred_min: 0.0072
#
# Epoch 00142: loss did not improve from 0.01245
# Epoch 143/150
# 40/40 [==============================] - 27s 666ms/step - loss: 0.0126 - y_true_max: 0.6996 - y_true_min: -0.6821 - y_pred_max: 0.0145 - y_pred_min: 0.0085 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0151 - val_y_pred_min: 0.0073
#
# Epoch 00143: loss did not improve from 0.01245
# Epoch 144/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0131 - y_true_max: 0.6955 - y_true_min: -0.6762 - y_pred_max: 0.0151 - y_pred_min: 0.0085 - val_loss: 0.0158 - val_y_true_max: 0.7269 - val_y_true_min: -0.8101 - val_y_pred_max: 0.0163 - val_y_pred_min: 0.0085
#
# Epoch 00144: loss did not improve from 0.01245
# Epoch 145/150
# 40/40 [==============================] - 27s 666ms/step - loss: 0.0126 - y_true_max: 0.6966 - y_true_min: -0.6798 - y_pred_max: 0.0146 - y_pred_min: 0.0073 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0148 - val_y_pred_min: 0.0068
#
# Epoch 00145: loss did not improve from 0.01245
# Epoch 146/150
# 40/40 [==============================] - 27s 663ms/step - loss: 0.0130 - y_true_max: 0.6974 - y_true_min: -0.6794 - y_pred_max: 0.0154 - y_pred_min: 0.0089 - val_loss: 0.0153 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0159 - val_y_pred_min: 0.0076
#
# Epoch 00146: loss did not improve from 0.01245
# Epoch 147/150
# 40/40 [==============================] - 27s 664ms/step - loss: 0.0129 - y_true_max: 0.6971 - y_true_min: -0.6744 - y_pred_max: 0.0146 - y_pred_min: 0.0081 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0152 - val_y_pred_min: 0.0074
#
# Epoch 00147: loss did not improve from 0.01245
# Epoch 148/150
# 40/40 [==============================] - 27s 665ms/step - loss: 0.0129 - y_true_max: 0.6977 - y_true_min: -0.6739 - y_pred_max: 0.0155 - y_pred_min: 0.0087 - val_loss: 0.0108 - val_y_true_max: 0.6597 - val_y_true_min: -0.4784 - val_y_pred_max: 0.0162 - val_y_pred_min: 0.0078
#
# Epoch 00148: loss did not improve from 0.01245
# Epoch 149/150
# 40/40 [==============================] - 27s 667ms/step - loss: 0.0129 - y_true_max: 0.6969 - y_true_min: -0.6771 - y_pred_max: 0.0155 - y_pred_min: 0.0076 - val_loss: 0.0092 - val_y_true_max: 0.7185 - val_y_true_min: -0.6835 - val_y_pred_max: 0.0149 - val_y_pred_min: 0.0069
#
# Epoch 00149: loss did not improve from 0.01245
# Epoch 150/150
# 40/40 [==============================] - 27s 672ms/step - loss: 0.0126 - y_true_max: 0.6963 - y_true_min: -0.6735 - y_pred_max: 0.0148 - y_pred_min: 0.0088 - val_loss: 0.0152 - val_y_true_max: 0.6753 - val_y_true_min: -0.7968 - val_y_pred_max: 0.0150 - val_y_pred_min: 0.0069
#
# Epoch 00150: loss did not improve from 0.01245
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7fcd64aefe80>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7fcc49cbcc50>) the dataset: <DatasetV1Adapter shapes: ((?, 128, 128, 1), (?, 128, 128, 2), (?, 1000)), types: (tf.float32, tf.float32, tf.float32)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7fcd64aefe80>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7fcc49cbcc50>) the dataset: <DatasetV1Adapter shapes: ((?, 128, 128, 1), (?, 128, 128, 2), (?, 1000)), types: (tf.float32, tf.float32, tf.float32)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7fcd64aefe80>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7fcc49cbcc50>) the dataset: <DatasetV1Adapter shapes: ((128, 128, 1), (128, 128, 2), (1000,)), types: (tf.float32, tf.float32, tf.float32)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7fcd64aefe80>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7fcc49cbcc50>) the dataset: <DatasetV1Adapter shapes: ((128, 128, 1), (128, 128, 2), (1000,)), types: (tf.float32, tf.float32, tf.float32)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7fcd64aefe80>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7fcc49cbcc50>) the dataset: <TFRecordDatasetV1 shapes: (), types: tf.string> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7fcd64aefe80>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7fcc49cbcc50>) the dataset: <TensorSliceDataset shapes: (), types: tf.string> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7fcd64aefe80>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7fcc49cbbba8>) the dataset: <DatasetV1Adapter shapes: ((?, 128, 128, 1), (?, 128, 128, 2), (?, 1000)), types: (tf.float32, tf.float32, tf.float32)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7fcd64aefe80>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7fcc49cbbba8>) the dataset: <DatasetV1Adapter shapes: ((?, 128, 128, 1), (?, 128, 128, 2), (?, 1000)), types: (tf.float32, tf.float32, tf.float32)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7fcd64aefe80>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7fcc49cbbba8>) the dataset: <DatasetV1Adapter shapes: ((128, 128, 1), (128, 128, 2), (1000,)), types: (tf.float32, tf.float32, tf.float32)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7fcd64aefe80>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7fcc49cbbba8>) the dataset: <DatasetV1Adapter shapes: ((128, 128, 1), (128, 128, 2), (1000,)), types: (tf.float32, tf.float32, tf.float32)> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7fcd64aefe80>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7fcc49cbbba8>) the dataset: <TFRecordDatasetV1 shapes: (), types: tf.string> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# WARNING:tensorflow:The graph (<tensorflow.python.framework.ops.Graph object at 0x7fcd64aefe80>) of the iterator is different from the graph (<tensorflow.python.framework.ops.Graph object at 0x7fcc49cbbba8>) the dataset: <TensorSliceDataset shapes: (), types: tf.string> was created in. If you are using the Estimator API, make sure that no part of the dataset returned by the `input_fn` function is defined outside the `input_fn` function.Please ensure that all datasets in the pipeline are created in the same graph as the iterator. NOTE: This warning will become an error in future versions of TensorFlow.
# Exception ignored in: <generator object val_batch_generator at 0x7fcc4907bfc0>
# Traceback (most recent call last):
#   File "<ipython-input-17-fd606f3dff74>", line 15, in val_batch_generator
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py", line 1587, in __exit__
#     self._default_graph_context_manager.__exit__(exec_type, exec_value, exec_tb)
#   File "/usr/lib/python3.5/contextlib.py", line 77, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py", line 5257, in get_controller
#     context.context().context_switches.pop()
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/eager/context.py", line 199, in pop
#     self.stack.pop()
# IndexError: pop from empty list
# Exception ignored in: <generator object train_generator at 0x7fcc4905f200>
# Traceback (most recent call last):
#   File "<ipython-input-16-054f9dc49f37>", line 15, in train_generator
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py", line 1587, in __exit__
#     self._default_graph_context_manager.__exit__(exec_type, exec_value, exec_tb)
#   File "/usr/lib/python3.5/contextlib.py", line 77, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py", line 5257, in get_controller
#     context.context().context_switches.pop()
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/eager/context.py", line 199, in pop
#     self.stack.pop()
# IndexError: pop from empty list

# %%
# test the model to colorize grayscaled images
TEST_IMAGE_PATH = r"../dd2424_project/imagenet_cat/images"

batch_size = 10
image_size = 128

X = []
orig_X = []
orig_Y = []
files = glob.glob(TEST_IMAGE_PATH+'*/*')
files = files[-10:]

model = gen_model()
model.load_weights('model_weights_class_overfit/color_model_cat.h5')

for i, file in enumerate(files):
    img = img_to_array(load_img(file))/255.
    temp_orig_X, temp_orig_Y = img.shape[0:2]
    orig_X.append(temp_orig_X)
    orig_Y.append(temp_orig_Y)
    img = resize(img, (image_size, image_size, 3))*255.
    X.append(img)
    
X = np.array(X, dtype='float')
X_lab, X_features = preprocess_input_img_batch(X, batch_size=batch_size)
predictions = model.predict([X_lab, X_features], batch_size, verbose=1)

postprocess_output_img(X_lab, predictions, orig_X, orig_Y, image_size=image_size)
# Out:
# Model built and compiled
# 10/10 [==============================] - 2s 209ms/step
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
